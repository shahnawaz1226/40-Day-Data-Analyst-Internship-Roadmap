# %% [markdown]
# orders.csv (order_id, customer, amount)
# Tasks:
#
# Total revenue
#
# Top 3 customers by spend

# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install seaborn

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('orders.csv')
df
# Out:
#    order_id customer  amount
# 0       101     Aman    1200
# 1       102     Riya    2500
# 2       103     Aman     800
# 3       104     Neha    3000
# 4       105     Riya    1500
# 5       106     Shiv     700
# 6       107     Neha    2000
# 7       108     Aman    1000

# %%
total_revenue = np.sum(df['amount'])
total_revenue
# Out:
# np.int64(12700)

# %%
customer_spend = df.groupby(by="customer")['amount'].sum()
customer_spend
# Out:
# customer
# Aman    3000
# Neha    5000
# Riya    4000
# Shiv     700
# Name: amount, dtype: int64

# %%
customer_spend.sort_values(ascending=False).head(3)
# Out:
# customer
# Neha    5000
# Riya    4000
# Aman    3000
# Name: amount, dtype: int64
