# %% [markdown]
# List lo:
#
# [10, 20, 30, 40, 50]
#
#
# NumPy array me convert
#
# Square of each number
#
# Pandas Series me convert karke print

# %%
import numpy as np
import pandas as pd

# %%
lst = [10, 20, 30, 40, 50]
arr_lst = np.array(lst)
arr_lst
# print(arr_lst)
# Out:
# array([10, 20, 30, 40, 50])

# %%
sqr_lst = arr_lst**2
sqr_lst
# Out:
# array([ 100,  400,  900, 1600, 2500])

# %%
series = pd.Series(sqr_lst)
series
# Out:
# 0     100
# 1     400
# 2     900
# 3    1600
# 4    2500
# dtype: int64
