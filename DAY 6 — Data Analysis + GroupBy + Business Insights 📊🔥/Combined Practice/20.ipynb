# %% [markdown]
# Questions
#
# Merge customer data with sales data.
#
# Find total revenue per customer.
#
# Which city generates the highest revenue?
#
# Average spending by gender.
#
# Create age groups:
#
# 18–25
#
# 26–35
#
# 36+
#
# Revenue contribution by age group (%).
#
# Customers with more than 1 order.
#
# Find repeat customers vs one-time buyers.
#
# Top 2 products by revenue in each city.
#
# Handle missing values (assume some ages are missing).

# %%
import pandas as pd
import numpy as np

# %%
df_customers = pd.read_csv('customer_data.csv')
df_customers
# Out:
#   customer_id  gender  age signup_date       city
# 0        C001    Male   24  2024-06-12      Delhi
# 1        C002  Female   29  2023-11-20     Mumbai
# 2        C003    Male   35  2022-01-05  Bangalore
# 3        C004  Female   27  2024-03-18      Delhi

# %%
df_customers = pd.merge(df, df_customers, on="customer_id", how="left")
df_customers
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/kf/46fvvcgx371d5df6s5n8qp_w0000gn/T/ipykernel_12038/1066004542.py in ?()
# ----> 1 df_customers = pd.merge(df, df_customers, on="customer_id", how="left")
#       2 df_customers
#
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
# ...
