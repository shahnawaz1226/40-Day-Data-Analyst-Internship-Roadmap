# %%
# Q1
# Create DataFrame:

# Name | Age
# A    | 21
# B    | 22
# C    | 20

# %%
import pandas as pd

# %%
Students ={
    "Name": ['A', 'B', 'C'],
    "Age": [21, 22, 20]
}

df = pd.DataFrame(Students)
df
# Out:
#   Name  Age
# 0    A   21
# 1    B   22
# 2    C   20

# %%
# Q2
# Print:
# first 2 rows
# last row
# shape
# columns

# %%
print(df.head(2))
# Out:
#   Name  Age
# 0    A   21
# 1    B   22

# %%
df.tail(1)
# Out:
#   Name  Age
# 2    C   20

# %%
df.shape
# Out:
# (3, 2)

# %%
df.columns
# Out:
# Index(['Name', 'Age'], dtype='object')
