# %%
# BONUS CHALLENGE 🔥

# Dataset:

# data = {
#     "Product": ["Laptop", "Phone", "Laptop", None],
#     "Price": [50000, None, 50000, 30000],
#     "City": [" Delhi ", "MUMBAI", " Delhi ", None]
# }

# Clean complete dataset professionally.

# %%
import pandas as pd

data = {
    "Product": ["Laptop", "Phone", "Laptop", None],
    "Price": [50000, None, 50000, 30000],
    "City": [" Delhi ", "MUMBAI", " Delhi ", None]
}

df = pd.DataFrame(data)

# %%
df.isnull().sum()
# Out:
# Product    1
# Price      1
# City       1
# dtype: int64

# %%
df['Product'] = df['Product'].fillna('Unknown')
df['Price'] = df['Price'].fillna(df['Price'].mean())
df['City'] = df['City'].fillna('Unknown')
df['City'] = df['City'].str.strip()
df['City'] = df['City'].str.lower()
df = df.drop_duplicates()

# %%
df
# Out:
#    Product         Price     City
# 0   Laptop  50000.000000    delhi
# 1    Phone  43333.333333   mumbai
# 3  Unknown  30000.000000  unknown

# %%
# TODAY’S INTERVIEW QUESTIONS
# Prepare answers:

# 1.
# What is data cleaning?

# 2.
# Why handling missing values important?

# 3.
# Difference between dropping and filling null values?

# 4.
# What are duplicate rows?

# 5.
# Why string cleaning important?

# %%
# 1. What is Data Cleaning?

# Data cleaning ka matlab:
# Raw data ko accurate, consistent, aur usable banana.

# Isme:

# Missing values handle karna
# Duplicates remove karna
# Wrong formatting fix karna
# Incorrect data clean karna
# Practical Example:
# df["City"] = df["City"].str.strip().str.lower()
# Interview Line:

# “Data cleaning is the process of fixing or removing incorrect, incomplete, or inconsistent data before analysis.”

# 2. Why is handling missing values important?

# Missing values analysis ko wrong bana sakte hain.
# Agar null values handle nahi karoge:

# calculations wrong ho sakti hain
# model accuracy reduce ho sakti hai
# reports misleading ho sakte hain
# Practical Example:
# df["Age"].fillna(df["Age"].mean(), inplace=True)
# Interview Line:

# “Handling missing values is important to improve data quality and ensure accurate analysis.”

# 3. Difference between dropping and filling null values?
# Dropping Nulls	Filling Nulls
# Missing rows/columns remove kar deta hai	Missing values replace karta hai
# Data loss ho sakta hai	Data preserve rehta hai
# Use when too many nulls	Use when data important ho
# Practical Example:
# # Drop null values
# df.dropna()

# # Fill null values
# df.fillna(0)
# Interview Line:

# “Dropping removes missing data completely, while filling replaces missing values with meaningful values like mean, median, or default data.”

# 4. What are Duplicate Rows?

# Duplicate rows wo rows hoti hain jo same data multiple times contain karti hain.

# Ye analysis ko inaccurate bana sakti hain.

# Practical Example:
# df.drop_duplicates(inplace=True)
# Interview Line:

# “Duplicate rows are repeated records in a dataset that can affect analysis accuracy and should usually be removed.”

# 5. Why is String Cleaning Important?

# String cleaning important hai because text data messy ho sakta hai:

# extra spaces
# inconsistent capitalization
# spelling variations

# Ye filtering aur analysis me problems create karta hai.

# Practical Example:
# df["City"] = df["City"].str.strip().str.upper()
# Interview Line:

# “String cleaning helps standardize text data, making analysis more accurate and consistent.”

# Quick smart line for interview 😎
# Agar interviewer bole:
# “What’s the first thing you do in data cleaning?”

# Tu bol:

# “I first check missing values, duplicates, incorrect datatypes, and inconsistent formatting.”

# Clean. Professional. Straight to the point.
